# %% [markdown]
# # Analysis of Public Comments Regarding the EPA's Revised Definition of "Waters of the United States" (WOTUS)
#
# In early 2017, President Trump signed an Executive Order<sup>[1](#footnote1)</sup> requesting that agencies review a 2015 rule regarding the "Waters of the United States". The agencies, including the Environmental Protection Agency (EPA) and the Department of the Army, were instructed to rescind or replace the rule, in accordance with law.
#
# The agencies have since conducted a reevaluation and revision of the definition of "Waters of the United States". Their proposed rule redefines the scope of waters federally regulated under the Clean Water Act (CWA). This rule was open for public comment until April 15, 2019.
#
# This project aims to apply Natural Language Processing (NLP) techniques to analyze the content of comments that are publicly available on the [regulations.gov web page](https://www.regulations.gov/docket?D=EPA-HQ-OW-2018-0149) for this docket. For technical reasons (see the [Data_Prep notebook](./Data_Prep.ipynb)), the dataset only includes ~8K comments, which are the ones typed directly onto the site. The dataset excludes another ~3K comments submitted in an attachment form (most of which were PDFs).
#
# Notes:
#
# <a name="footnote1">1</a>: Executive Order 13778, signed on February 28, 2017, titled "Restoring the Rule of Law, Federalism, and Economic Growth by Reviewing the 'Waters of the United States' Rule"

# %% [markdown]
# ## Library Imports

# %%
# Standard imports
import re
import warnings
warnings.filterwarnings('ignore', 'DeprecationWarning') 

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Model and analysis imports
from scipy import linalg

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer, HashingVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import LatentDirichletAllocation as LDA, NMF, PCA
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn import metrics
from sklearn.manifold import TSNE

from wordcloud import WordCloud

# %%
full_df = pd.read_pickle('./Data/full_df.pkl')

full_df.head()
# Out:
#                    Document Title               Document ID Posted Date  \
# 0        Anonymous public comment  EPA-HQ-OW-2018-0149-6689  2019-04-29
# 1        Anonymous public comment  EPA-HQ-OW-2018-0149-6688  2019-04-29
# 2        Anonymous public comment  EPA-HQ-OW-2018-0149-7377  2019-05-01
# 3        Anonymous public comment  EPA-HQ-OW-2018-0149-6707  2019-04-29
# 4  Comment submitted by T. Dahlin  EPA-HQ-OW-2018-0149-7983  2019-05-01
#
#   Received Date Document SubType Post Mark Date  \
# 0    2019-04-11   Public Comment     04/11/2019
# 1    2019-04-11   Public Comment     04/11/2019
# 2    2019-04-11   Public Comment     04/11/2019
# 3    2019-04-11   Public Comment     04/11/2019
# 4    2019-04-12   Public Comment     04/12/2019
#
#                                      Document Detail  \
# 0  https://www.regulations.gov/document?D=EPA-HQ-...
# 1  https://www.regulations.gov/document?D=EPA-HQ-...
# 2  https://www.regulations.gov/document?D=EPA-HQ-...
# 3  https://www.regulations.gov/document?D=EPA-HQ-...
# 4  https://www.regulations.gov/document?D=EPA-HQ-...
#
#                                              Comment
# 0  I write to express my opposition to the Enviro...
# 1  I write to express my opposition to the Enviro...
# 2  Please abandon this proposed rollback of the 2...
# 3  My husband and I have two wonderful daughters,...
# 4  Please do not change the definitions within th...

# %% [markdown]
# ## Topic Analysis

# %%
# Process comment column for topic analysis

# Remove punctuation
full_df['Comment_processed'] = full_df['Comment'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the comments to lowercase
full_df['Comment_processed'] = full_df['Comment'].map(lambda x: x.lower())

full_df.head()
# Out:
#                    Document Title               Document ID Posted Date  \
# 0        Anonymous public comment  EPA-HQ-OW-2018-0149-6689  2019-04-29
# 1        Anonymous public comment  EPA-HQ-OW-2018-0149-6688  2019-04-29
# 2        Anonymous public comment  EPA-HQ-OW-2018-0149-7377  2019-05-01
# 3        Anonymous public comment  EPA-HQ-OW-2018-0149-6707  2019-04-29
# 4  Comment submitted by T. Dahlin  EPA-HQ-OW-2018-0149-7983  2019-05-01
#
#   Received Date Document SubType Post Mark Date  \
# 0    2019-04-11   Public Comment     04/11/2019
# 1    2019-04-11   Public Comment     04/11/2019
# 2    2019-04-11   Public Comment     04/11/2019
# 3    2019-04-11   Public Comment     04/11/2019
# 4    2019-04-12   Public Comment     04/12/2019
#
#                                      Document Detail  \
# 0  https://www.regulations.gov/document?D=EPA-HQ-...
# 1  https://www.regulations.gov/document?D=EPA-HQ-...
# 2  https://www.regulations.gov/document?D=EPA-HQ-...
# 3  https://www.regulations.gov/document?D=EPA-HQ-...
# 4  https://www.regulations.gov/document?D=EPA-HQ-...
#
#                                              Comment  \
# 0  I write to express my opposition to the Enviro...
# 1  I write to express my opposition to the Enviro...
# 2  Please abandon this proposed rollback of the 2...
# 3  My husband and I have two wonderful daughters,...
# 4  Please do not change the definitions within th...
#
#                                    Comment_processed
# 0  i write to express my opposition to the enviro...
# 1  i write to express my opposition to the enviro...
# 2  please abandon this proposed rollback of the 2...
# 3  my husband and i have two wonderful daughters,...
# 4  please do not change the definitions within th...

# %%
comments = full_df['Comment_processed']

comments.head()
# Out:
# 0    i write to express my opposition to the enviro...
# 1    i write to express my opposition to the enviro...
# 2    please abandon this proposed rollback of the 2...
# 3    my husband and i have two wonderful daughters,...
# 4    please do not change the definitions within th...
# Name: Comment_processed, dtype: object

# %%
# Helper function to show top words per topics
def show_topics(Vh, vocab_array, n_top_words=8):
    """
    Returns a list of the n_top_words from topic matrix Vh
    :param Vh: a topic-by-vocabulary orthonormal matrix
    :param vocab_array: a Numpy array of the vocabulary terms
        from the documents used in the analysis
    :param n_top_words: int of how many words to show by topic
    :return: list of strings with top words by topic in Vh
    
    >>>show_topics(my_Vh_matrix[:4], vocab)
    ['space launch satellite nasa commercial market satellites data',
     'god atheists atheism religious believe argument religion true',
     'nasa space lunar available mars probe moon edu',
     'atheists religious atheism god religion believe belief atheist']
    """
    top_words = lambda t: [vocab_array[i] for i in np.argsort(t)[:-n_top_words-1:-1]]
    topic_words = ([top_words(t) for t in Vh])
    return [' '.join(t) for t in topic_words]

# %%
# Helper function to plot most common words
def plot_most_common_words(count_data, count_vect, n=10):
    """
    :param count_data: data after running a CountVectorizer.fit_transform()
    :param count_vect: a CountVectorizer() instance
    :param n: int for how many top words to plot
    :return: None; plots a matplotlib.pyplot bar chart of top n words
    """
    import matplotlib.pyplot as plt
    
    words = count_vect.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts += t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:n]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 

    plt.bar(x_pos, counts,align='center')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('Words')
    plt.ylabel('Counts')
    plt.title('{} Most Common Words'.format(n))
    plt.show()

# %%
# Transform comments to a matrix of comments by word counts
#   then to normalized TF-IDF representation

# Create frequency counts and generate corpus vocabulary
count_vec = CountVectorizer(stop_words='english')
count_data = count_vec.fit_transform(comments)
print(count_data.shape)

# Create array of vocabulary terms
vocab = np.array(count_vec.get_feature_names())

# Calculate TF-IDF stats
tfidf = TfidfTransformer()
tfidf_data = tfidf.fit_transform(count_data)
print(tfidf_data.shape)
# Out:
# (8187, 22434)
# (8187, 22434)

# %%
# Test just TFIDF vectorizer
tf_vec = TfidfVectorizer(stop_words='english')
tfv_data = tf_vec.fit_transform(comments)
vocab_2 = np.array(tf_vec.get_feature_names())
print(tfv_data.shape)
# Out:
# (8187, 22434)

# %%
s = 1100
print(vocab[s:s+100])
# Out:
# ['abomination' 'abound' 'abounds' 'aboutepa' 'aboveground' 'aboveis' 'abq'
#  'abraham' 'abrahams' 'abrahamson' 'abrams' 'abreast' 'abridge' 'abridged'
#  'abroad' 'abrogated' 'abrogation' 'abrsorbing' 'abruptly' 'absence'
#  'absent' 'absolute' 'absolutely' 'absolve' 'absorb' 'absorbed'
#  'absorbing' 'absorbs' 'absorption' 'abstention' 'abstract' 'absurd'
#  'absurdities' 'absurdity' 'absurdly' 'abudent' 'abudt' 'abundance'
#  'abundant' 'abundent' 'abuse' 'abused' 'abuses' 'abusing' 'abusive'
#  'abut' 'abuting' 'abuts' 'abutted' 'abutting' 'abysmal' 'academia'
#  'academic' 'academically' 'academy' 'accelerate' 'accelerated'
#  'accelerates' 'accelerating' 'accept' 'acceptability' 'acceptable'
#  'acceptance' 'accepted' 'acceptible' 'accepting' 'accepts' 'access'
#  'accesse' 'accessed' 'accessibility' 'accessible' 'accessing'
#  'accheivment' 'accident' 'accidental' 'accidentally' 'accidents'
#  'accolades' 'accomadate' 'accommodate' 'accommodating' 'accomodate'
#  'accompanied' 'accompanies' 'accompany' 'accompanying' 'accompilsh'
#  'accomplish' 'accomplished' 'accomplishes' 'accomplishing'
#  'accomplishment' 'accord' 'accordance' 'according' 'accordingly'
#  'accotink' 'account' 'accountability']

# %%
plot_most_common_words(tfidf_data, count_vec)

# %% [markdown]
# ### Word Cloud

# %%
# Combine comments into one "text"
text = ' '.join(comments)

wordcloud = WordCloud(width = 800,
                      height = 800, 
                      background_color ='white',
                      min_font_size = 10).generate(text)

# Plot the word cloud
plt.figure(figsize = (8, 8), facecolor=None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad=0)  
plt.show()

# %% [markdown]
# ### Singular Value Decomposition (SVD) Analysis

# %%
# Run SVD to create topic matrices
U, s, Vh = linalg.svd(tfv_data.todense(), full_matrices=False)
print(U.shape, s.shape, Vh.shape)
# Out:
# (8187, 8187) (8187,) (8187, 22434)

# %%
# Plot s to see where topic importance drops off
plt.plot(range(1, 11), s[:10]);

# %%
# Print top 10 topics
show_topics(Vh[:10], vocab)
# Out:
# ['torrance rosamond winthrop devan faillacetarrytown jaegerssaint gratefully ironic',
#  'families proposal risky bipartisan love limits coastal waterways',
#  'communities dirty polluters instead safeguards jeopardy corporate abandon',
#  'rules farmers clear land support need farm follow',
#  'waters united states dangerous definition dirty revised agencys',
#  'united dangerous states dirty waters concerned harmed protections',
#  'park parks small clean country downstream control roll',
#  'park parks water quality vital roll country adapt',
#  'waterways wotus definition percent waters changes states categories',
#  'waterways categories percent rules recreate unprotected nevada arizona']

# %% [markdown]
# Aside from the gibberish that comprises the first topic, the others all seem to reasonably fit the core themes in the public comments.

# %% [markdown]
# ### LDA
#
# LDA analysis had much higher perplexity scores (12K vs 995 at 12 topics) using the TF-IDF count data vs. the standard count vectorizer.

# %%
n_topics = 12

# Create and fit an LDA model
lda = LDA(n_components=n_topics,
          n_jobs=-1,
          random_state=42)

lda.fit(count_data)  # tfidf_data had much higher perplexity scores
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=12, n_jobs=-1,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
lda.components_.shape
# Out:
# (12, 22434)

# %%
print('Final perplexity score: {0:,.0f}'.format(lda.bound_))
# Out:
# Final perplexity score: 995

# %%
show_topics(lda.components_, vocab)
# Out:
# ['water rules clean rule farmers land clear support',
#  'water clean act waterways streams proposal waters drinking',
#  'waters definition wotus regulation property water states regards',
#  'water rivers new streams industry creeks life pollute',
#  'water wetlands waters rule proposed streams clean protection',
#  'water waters states united definition act clean regulations',
#  'water clean people life protect environment need future',
#  'water clean waters protections wetlands streams act rule',
#  'rule proposed water waters definition epa wotus support',
#  'water streams wetlands clean rule downstream proposed waterways',
#  'water clean rule communities waterways epa wetlands polluters',
#  'regards comment write irrigation wheeler mr people idaho']

# %%
# Compare perplexity scores for various number of topics
p = []

for n in range(2, 19, 2):
    mod = LDA(n_components=n,
              n_jobs=-1,
              random_state=42)
    mod.fit(count_data)
    p.append(mod.bound_)
    print('Number of Topics: {}'.format(n))
    print('Perplexity score: {0:,.0f}'.format(mod.bound_))
    print('----------------')
# Out:
# Number of Topics: 2
# Perplexity score: 1,236
# ----------------
# Number of Topics: 4
# Perplexity score: 1,147
# ----------------
# Number of Topics: 6
# Perplexity score: 1,110
# ----------------
# Number of Topics: 8
# Perplexity score: 1,071
# ----------------
# Number of Topics: 10
# Perplexity score: 1,022
# ----------------
# Number of Topics: 12
# Perplexity score: 995
# ----------------
# Number of Topics: 14
# Perplexity score: 979
# ----------------
# Number of Topics: 16
# Perplexity score: 976
# ----------------
# Number of Topics: 18
# Perplexity score: 965
# ----------------

# %%
# Plot the perplexity scores
plt.plot(range(2, 19, 2), p);
plt.title('LDA Perplexity Score by Topic Number');
plt.ylabel('Perplexity Score');
plt.xlabel('Number of Topics');

# %% [markdown]
# The sharpest decline in perplexity score happens from two to four topics, with steady declines until 10-12 topics. After that point, the scores still drop but at a much slower rate.

# %% [markdown]
# ### NMF

# %%
# Create and fit an NMF model with just CountVectorizer
nmf = NMF(n_components=n_topics,
          random_state=42)

W1 = nmf.fit_transform(count_data)
H1 = nmf.components_

# %%
show_topics(H1, vocab)
# Out:
# ['water clean act protections protect drinking river life',
#  'waters states united definition federal act navigable ephemeral',
#  'streams wetlands downstream rule proposed flow small rivers',
#  'waterways water act proposal streams families waters drinking',
#  'rule proposed epa wotus case 2015 support environmental',
#  'water farmers rules land rule epa clear new',
#  'waterways rule proposed streams wetlands new categories protections',
#  'water protections park streams quality wetlands clean parks',
#  'waters united states dirty rule dangerous people water',
#  'water clean communities rule epa polluters waterways dirty',
#  'water definition wotus proposed drinking cwa bodies rule',
#  'wetlands streams protection wetland epa wildlife species ecosystems']

# %%
# Create and fit an NMF model with TF-IDF Vectorizer
nmf_tf = NMF(n_components=n_topics,
          random_state=42)

W1_tf = nmf_tf.fit_transform(tfv_data)
H1_tf = nmf_tf.components_

# %%
show_topics(H1_tf, vocab)
# Out:
# ['definition wotus waters rule states united 2015 proposed',
#  'water waterways families act proposal clean streams love',
#  'water communities clean dirty polluters instead rule families',
#  'rules farmers land clear water support new landowners',
#  'concerned harmed protections overall remove loss rappahannock impact',
#  'dangerous dirty united waters states agencys water jeopardize',
#  'blanket handout arroyos acequias disregards connectivity cinegas imperative',
#  'park parks water protections wetlands quality streams small',
#  'downstream streams wetlands flow small rule allowing water',
#  'waterways categories proposed unprotected recreate mexico arizona nevada',
#  'water clean life act protect need people regulations',
#  'niagara usepa percent wetlands streams buffalo waters including']

# %%
# Create and fit an NMF model with CountVectorizer then TF-IDF Transformer
nmf_ctf = NMF(n_components=n_topics,
          random_state=42)

W1_ctf = nmf_ctf.fit_transform(tfidf_data)
H1_ctf = nmf_ctf.components_

# %%
show_topics(H1_ctf, vocab)
# Out:
# ['definition wotus waters rule states united 2015 proposed',
#  'water waterways families act proposal clean streams love',
#  'water communities clean dirty polluters instead rule families',
#  'rules farmers land clear water support new landowners',
#  'concerned harmed protections overall remove loss rappahannock impact',
#  'dangerous dirty united waters states agencys water jeopardize',
#  'blanket handout arroyos acequias disregards connectivity cinegas imperative',
#  'park parks water protections wetlands quality streams small',
#  'downstream streams wetlands flow small rule allowing water',
#  'waterways categories proposed unprotected recreate mexico arizona nevada',
#  'water clean life act protect need people regulations',
#  'niagara usepa percent wetlands streams buffalo waters including']

# %% [markdown]
# As expected, this outcome matches the TF-IDF vectorizer - sometimes it's nice to verify the claim that the same math is performed under the hood.

# %% [markdown]
# ## Clustering Analysis

# %%
# Create dataset from original comments; form training/test sets
X = full_df['Comment']

X_train, X_test = train_test_split(X,
                                   test_size=.2,
                                   random_state=42)

print(X_train.shape, X_test.shape)
# Out:
# (6549,) (1638,)

# %%
# Create various options for the word vectorizer
n_feats = 5000
use_bigrams = False

if use_bigrams:
    b = 2
else:
    b = 1

# Comment out all vectorizer defs except the one to use
# Simple count vectorizer
# vectorizer = CountVectorizer(stop_words='english',
#                              ngram_range=(1, b),
#                              max_features=n_feats)

# Hashing vectorizer using L2 norm
vectorizer = HashingVectorizer(stop_words='english',
                               n_features=n_feats,
                               ngram_range=(1, b),
                               norm='l2')

# Hashing vectorizer normalized using TF-IDF
# hashy = HashingVectorizer(n_features=n_feats,
#                            stop_words='english',
#                            ngram_range=(1, b),
#                            norm=None)

# vectorizer = make_pipeline(hashy, TfidfTransformer())

# TF-IDF vectorizer
# vectorizer = TfidfVectorizer(max_features=n_feats,
#                              ngram_range=(1, b),
#                              stop_words='english')

# %%
# Transformed features
X_data = vectorizer.fit_transform(X_train)
print(X_data.shape)
# Out:
# (6549, 5000)

# %%
# Create and fit a KMeans algorithm
kmeans = KMeans(n_clusters=2,
                max_iter=100,
                n_init=1,
                n_jobs=-1)

kmeans.fit(X_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=2, n_init=1, n_jobs=-1, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Examine metrics for KMeans
# print(kmeans.labels_)
print('Inertia: {0: .3f}'.format(kmeans.inertia_))
print('Silhouette Coefficient: {0:.3f}'.format(
      metrics.silhouette_score(X_data, kmeans.labels_, sample_size=1000)))
# Out:
# Inertia:  4879.316
# Silhouette Coefficient: 0.072

# %%
# Compare metrics of different number of clusters
n_clusters = list(range(2, 13))
inertias = []
silhouettes = []

for n in n_clusters:
    model = KMeans(n_clusters=n,
                   max_iter=100,
                   n_init=1,
                   n_jobs=-1)
    model.fit(X_data)
    inertias.append(model.inertia_)
    silhouettes.append(metrics.silhouette_score(X_data, model.labels_, sample_size=1000))

# %%
# Plot scores by cluster
plt.subplots(1, 2, figsize=(15, 6))

# Cluster-inertia plot
plt.subplot(1, 2, 1);
plt.plot(n_clusters, inertias, 'bo--');
plt.xlabel('Number of Clusters');
plt.ylabel('Inertia Score');
plt.title('KMeans: Inertia Score by Cluster Count\nFeatures: {}'.format(X_data.shape[1]));

# Cluster-silhouette score plot
plt.subplot(1, 2, 2);
plt.plot(n_clusters, silhouettes, 'ro--');
plt.xlabel('Number of Clusters');
plt.ylabel('Silhouette Score');
plt.title('KMeans: Silhouette Score by Cluster Count');

# plt.savefig('./Figures/KMeans_HashingL2_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_HashingL2_Bigrams_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_HashingL2_5000_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_HashingL2_5000_Bigrams_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_Count_5000_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_HashingTFIDF_Inertia-Silhouette.png');
# plt.savefig('./Figures/KMeans_TFIDF_Inertia-Silhouette.png');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-13abb82e9f34> in <module>
#       4 # Cluster-inertia plot
#       5 plt.subplot(1, 2, 1);
# ----> 6 plt.plot(n_clusters, inertias, 'bo--');
#       7 plt.xlabel('Number of Clusters');
#       8 plt.ylabel('Inertia Score');
#
# NameError: name 'n_clusters' is not defined

# %% [markdown]
# **Inertia** calculates the sum of the squared distances between data points and their nearest cluster. Low overall values of inertia are generally better, but it will naturally favor having more clusters.
#
# **Silhouette score** uses two scores to find the mean distance between each observation and all others - both in the same cluster and then in the nearest cluster. Values range from -1 to 1, where a score of 1 indicates the point is close to others in the same cluster, but far away from the next cluster over. A score near -1 indicates the point is not near ones in its cluster but close to the next nearest cluster. And a score of 0 indicates overlapping clusters, where an observation is close to the decision boundary. A score closest to 1 is ideal, as that indicates tight, highly separable clusters.
#
# The KMeans algorithm was run with four different pre-processing applications, then using unigrams only vs. also including bigrams. Including bigrams did not generally improve the metrics, therefore the charts weren't included below.

# %% [markdown]
# 1) **Hashing Vectorizer with L2 Norm**
#
# ![Inertia and silhouette scores by cluster](./Figures/KMeans_HashingL2_Inertia-Silhouette.png)
#
# This method had the lowest overall inertia values and second highest overall silhouette scores.
#
# While the inertia score is the highest for two clusters (as expected), the silhouette score favors two clusters as being the optimal number. This aligns with the nature of the dataset having sets of comments from two distinct groups: those that support the rule change and those that oppose it.
#
# There are two trends worth pointing out in these chart. One is the jump from eight clusters to nine - there's little improvement to the inertia calculation, but almost a 4x improvement of silhouette score. This is repeated to a lesser degree in the move from ten to eleven clusters. The other is the move from four to five clusters - there's a steady decrease in inertia but an almost 2x increase in the silhouette score.

# %% [markdown]
# 2) **Count Vectorizer**
#
# ![Count vectorizer plots](./Figures/KMeans_Count_5000_Inertia-Silhouette.png)
#
# The count vectorizer plots had inertia values that were a factor of a hundred higher than all the others, but managed the highest overall silhouette scores, with the peak value over 0.3 at two clusters.

# %% [markdown]
# 3) **Hashing Vectorizer Normalized using TF-IDF**
#
# ![Inertia and silhouette scores by cluster](./Figures/KMeans_HashingTFIDF_Inertia-Silhouette.png)
#
# This analysis shows a completely different story, indicating that ten clusters is optimal. That cluster count has both the minimum inertia value as well as the peak silhouette score. However, the overall inertia and silhouette values are worse than the previous analysis using an L2 norm. The inertia scores are all higher, and the best silhouette score is still below the two-cluster score from before.

# %% [markdown]
# 4) **TF-IDF Vectorizer**
#
# ![Inertia and silhouette scores by cluster](./Figures/KMeans_TFIDF_Inertia-Silhouette.png)
#
# Not surprisingly, this analysis is more similar to the hashing vectorizer with TF-IDF normalization than the hashing vectorizer with an L2 norm. The overall score values are in line with where they fell out in the other TF-IDF-based analysis. Nine seems to be a good choice of clusters, with its dip in inertia and jump in silhouette scores (especially off the trough at eight clusters). However, the silhouette scores continue to climb at the limit of twelve clusters, indicating there could be better performance.

# %%
# Print comments from cluster 0
cluster_0 = X_train[kmeans.labels_ == 0]

for row in cluster_0.head(20):
    print(row)
    print('\n----------\n')
# Out:
# We da people have da power to send u to Washington with our votes,should be ashamed to take our property rights,may this world find da Lord's mercy especially TV those that abuse da system...!! Regards, William Perez
#
# ----------
#
# April 15, 2019U.S. Environmental Protection Agency EPA Docket Center Office of Water DocketMail Code 28221T 1200 Pennsylvania Avenue, NWWashington, DC 20460RE:Docket ID No. EPA-HQ-OW-2018-0149To Whom it May Concern:I am a farmer in Champaign county, Illinois. I am writing to submit comments to the United States Environmental Protection Agency (EPA) and the United States Army Corps of Engineers (Corps) in support of the proposal for the revised definition of Waters of the United States under the Clean Water Act.It is time for clear rules that protect both the nations water bodies and farmers ability to produce food, fiber and fuel. This proposed rule would have the ability to end years of uncertainty over where the jurisdiction of EPA and the Corps begins and ends. We need a new common-sense water rule that protects water quality and gives me clear rules I can follow. This new proposed rule would ensure that I dont need a team of lawyers or consultants to tell me what is, and what is not, regulated by EPA and the Corps.  The 2015 rule, by contrast, provided none of the clarity and certainty it promised. Instead, the rules gave EPA and the Corps virtually unlimited authority to regulate, at their discretion, navigable waters. My wife and I are fourth generation farmers who are striving to ensure our family farm will be sustainable for generations to come.  We are following in the footsteps of previous generations who have worked to implement practices to maintain the quality of our land.  We have had and continue to have acres in the conservation reserve program as well as utilizing filter strips, no till/minimal till farming, and working with our suppliers to apply fertilizers according to the 4Rs.  Our family is also active with local drainage districts and the farm bureau to make sure we can help in areas off our own family farm.  We are continually reviewing our practices in order to make sure we can protect our soil and water quality so that future generations can continue to prosper from the land.I strongly welcome the proposed rule as it protects water resources, respects the law and provides greater clarity so the agencies, farmers and the public can identify regulated federal waterways. Sincerely, Michael Briggs504 Landen Ln Fisher, IL 61843
#
# ----------
#
# PLEASE WRITE YOUR COMMENT HERE: Fund the Border wall and protect Americans with the border wall, sad that 4,000 American Citizens die each year at the hands of Ilegal Criminal Aliens. That is one to many deaths 36,000 a year face sexual assult from an Ilegal Criminal Alien , that's one to many sexual assult. Let me ask you this... what comes across the border (Ilegally) that someone profits off of and is the reason they fight so hard to keep the wall from being constructed? Regards, Richard Zentner
#
# ----------
#
# PLEASE WRITE YOUR COMMENT HERE:REPEAL Obamas Crooked Waters of the United States NOW Regards, Clarita Gonzalez
#
# ----------
#
# The terms in this legislation are far too vague and open to dangerous misinterpretation and misunderstanding. The definition of "adjacent" denies the connections among our waterways. In addition, we simply no longer have "typical years" due to climate change. To make calculations based on a non-existent "typical" opens the door to all kinds of small and large-scale damage to our waterways. This proposed rule doesn't protect clean waters. It's a rollback of existing rules that protect our waters much more effectively. Wetland ecosystems must be maintained to provide flood mitigation in years with heavy rains. This proposal would also impact many species living in, on, or near our waters.
#
# ----------
#
# Our waters need to be protected not weakened by eliminating certain areas from protection. As long as we are in an area prone to floods, and as long as we have people who dump waste in these areas we have a major problem that will only get worse if the proposed Clean Water Act changes are made. Our legislators must understand the science  behind this and the impact that it has on every single person. We are suppose to be stewards of this earth, to protect and take care of all, not close off our minds ,ears ,and eyes to the decisions we make and the dire consequences that will come from these horrible decisions.
#
# ----------
#
# G. Mintun- I live near the Rappahanock River and I want to keep it safe and still make sure the water is safe to drink.
#
# ----------
#
# We are grateful for the efforts Congress has made to permanently repeal the 2015 rule concerning which waters are subject to federal jurisdiction over 'Waters of the United States' (WOTUS). As both Democrats and Republicans in state and federal office have argued, the 2015 WOTUS rule signified a massive government overreach. It endowed the EPA and Army Corps with an unprecedented permitting and enforcement authority over land use decisions that went far beyond what Congress authorized under the Clean Water Act. In doing so, it undermined state authority and unduly infringed on land use and development nationwide. Congress has taken several key steps to right this, but it is crucial that the agency rulemaking now underway codifies a repeal of the flawed 2015 rule. We are calling on you to encourage support for a revised WOTUS rule that protects our nation's waters and provides clarity for states and stakeholders by: -Including clear definitions based on objectively identifiable characteristics; - Aligning with congressional intent under the Clean Water Act; and -Respecting the CWA's cooperative federalism structure by preserving the primary role of states in protecting water quality. Now more than ever we need a commonsense WOTUS rule that protects clean water and provides clear rules for individuals and states. A patchwork of court decisions determining which WOTUS definition applies by region or jurisdiction is untenable for state and local governments, small business owners, farmers and ranchers, and other landowners and developers. Thank you for your consideration.
#
# ----------
#
# This reduction of federal oversight on the protection of US waters will have disastrous effects on our nation's natural resources.  All waters are connected and it is illogical limit the federal oversight of something that so clearly crosses state lines.  I urge the EPA to maintain the broader definition of the Water of the US and strengthen, rather than weaken, federal action against water pollution.
#
# ----------
#
# We need you to please protect clean water and healthy rivers. do not revise our definition of waters.  Trumps new water rule disregards the connectivity and integrity of our watersheds and provides a blanket handout to industry to destroy, fill, and pollute the rivers, creeks, wetlands, and streams.  We shouldn't be moving backwards in time---we must be thinking of the future and building upon the environmental protections we already have.  Are we really going to let one ignorant person mess this up for ALL of us AND for future generations?
#
# ----------
#
# The proposed rule's definitions do not protect a large portion of waters of the U.S.  When you ignore science and logic concerning how watersheds work, then the purpose and intent of the Clean Water Act is violated.My heart ached while reading the waters you intend to exclude.Here in Southeast Alaska, I am surrounded by water and wetlands.  The value of our various wetlands is huge in their ability to protect downstream waters, air quality, aquatic and other species, etc.  While the linkages between wetlands and other waters are complex, it isn't rocket science, and we have perfectly good science to support including wetlands which you are choosing to exclude. I have also lived in parts of the country where waters have been severely, degraded--by agriculture, grazing, mining, and factory discharges. Again, the science is there to support inclusion of the waters you are choosing to exclude.If you err on the side of "overprotecting" U.S. waters from pollution or destruction, we and generations to come will be better off.  On the other hand, if you err on underprotecting these waters,  substantial damage can be done in fragile watersheds in the blink of an eye.  Large corporations, many non-American, are poised to make a fortune from degradation of our waters.   It is not 1898 or 1950, when we didn't have  abundant documented science about the importance of and the hidden linkages between waterbodies and wetlands and the significance of precipitation variation and irrigation waters.I'm 69 years old, and I had hoped that our understanding of how to prevent water pollution and degradation would evolve in a good direction during my lifetime.  Well, it has, since we definitely have a scientific body of knowledge to support inclusive Waters of the U.S. definitions.  I just fear that lobbyists for large corporations have your ear.Please fulfill your role as the ENVIRONMENTAL Protection Agency and include waters which you are currently excluding.  And thank you to all of you who are providing good science and logic to use in this decision making process.
#
# ----------
#
# April 5, 2019U.S. Environmental Protection Agency EPA Docket Center Office of Water DocketMail Code 28221T 1200 Pennsylvania Avenue, NWWashington, DC 20460RE:Docket ID No. EPA-HQ-OW-2018-0149To Whom it May Concern:I am a farmer in Effingham county, Illinois. I am writing to submit comments to the United States Environmental Protection Agency (EPA) and the United States Army Corps of Engineers (Corps) in support of the proposal for the revised definition of Waters of the United States under the Clean Water Act.It is time for clear rules that protect both the nations water bodies and farmers ability to produce food, fiber and fuel. This proposed rule would have the ability to end years of uncertainty over where the jurisdiction of EPA and the Corps begins and ends. We need a new common-sense water rule that protects water quality and gives me clear rules I can follow. This new proposed rule would ensure that I dont need a team of lawyers or consultants to tell me what is, and what is not, regulated by EPA and the Corps.  The 2015 rule, by contrast, provided none of the clarity and certainty it promised. Instead, the rules gave EPA and the Corps virtually unlimited authority to regulate, at their discretion, navigable waters. My farm has been in my family for over 100 years.  I raise livestock, therefore, I need to control the manure application so that there is no runoff into nearby streams.  I also plant cover crops near ditches and waterways to help control runoff and soil erosion.  I strongly welcome the proposed rule as it protects water resources, respects the law and provides greater clarity so the agencies, farmers and the public can identify regulated federal waterways. Sincerely, Kent Mellendorf18382 E 1st AveLouisville IL 62858kmellendorrf@wabash.net
#
# ----------
#
# The proposed rule change allowing pollutants to be dumped into local watersheds will decrease my property value and negatively affect my health. It was also hurt the tourism industry here in Buffalo, NY and result in the loss of jobs of people who depend on a healthy river. I live across the street from the Buffalo River which used to catch fire because of all the pollution dumped into it. Because of our local riverkeeper and other concerned people, we have a river on its way to good health now. Please, please do not undo decades of progress with this rule change. I've seen first-hand in my yard as wildlife has returned to the river and the bird population has risen because it's a healthier place for them now. As a member of this community, it's healthier for me too. And it's healthier for the people who fish from the river most weekdays and every weekend. Please do not change this rule and damage our river and our community when so much work has been done to restore it. We would never get back what we had in my lifetime. Please don't do it. Thank you, Emily Wester Lowrey Buffalo, NY
#
# ----------
#
# California Women for Agriculture supports the U.S. Environmental Protection Agency and the U.S. Army Corps of Engineers' Proposed Revised Definition of "Waters of the United States" (WOTUS) because it provides clarity and regulatory certainty for farmers and ranchers while protecting water resources. It is important for agriculture to have a common-sense water rule that protects water quality while minimizing regulatory uncertainty. The 2019 Proposed WOTUS Rule will help farmers and ranchers continue to be good stewards of land and water resources while growing food and fiber.  Additionally, the 2019 Proposed WOTUS Rule:Is consistent with both the statutory text of the Clean Water Act and the Constitution while respecting the federal-state balance that Congress outlined in the Clean Water Act; Alleviates the unpredictable and often inconsistent case-by-case determinations of "significant nexus" determinations;Provides much needed regulatory clarity;Provides for a common-sense definition of tributary;Provides a definition for adjacent wetlands that respects the federal-state balance;Excludes groundwater, including subsurface drainage systems;Clarifies and reinforces that prior converted cropland is not WOTUS; andProvides explicit regulatory exclusions important to agriculture, such as exclusions for many ditches, artificial lakes and ponds, artificially irrigated areas, and stormwater control features constructed in uplands.   The long-term success of farming is dependent on a healthy environment.  Activity on farmlands enhances the environment.  Farmers continually balance living off the land with being good stewards of the land. For this reason, we strongly support the 2019 Proposed WOTUS Rule.Respectfully submitted,Sara Reid HermanPresident California Women For Agriculture
#
# ----------
#
# Vernal pools are a core element of biological systems in large sections of the United States. Removing protections of them accelerates the degradation of ecosystems that we all benefit from. The proposed action further displays the kind of ignorance of environmental cause and effect that has already created many long term problems, many of which will outlast the current fact deniers and short term thinkers we're currently stuck with.
#
# ----------
#
# Thank you for considering my opinion regarding property rights.I have worked hard to give my family a piece of land to develop and use for generations.  When my government thinks they have a better use for my property,  I will listen...but this invasion of my family rights is not a government administration I will roll over and submit. With all sincerity, repeal this lawlessness. Regards, John Sederstrand
#
# ----------
#
# Comment: The proposed WOTUS rule is an attempt to NULLIFY a controlling opinion in the Rapanos U.S. Supreme Court decision that is now established law in the United States, in attempt to reduce Clean Water Act jurisdiction over areas that meet a controlling definition of waters of the United States.Discussions: The Rapanos decision established 2 tests for determining jurisdiction under the CWA: 1) the plurality + Kennedy opinion; and 2) the dissent + Kennedy opinion. CWA jurisdiction, as determined under Rapanos, can be asserted if EITHER of those tests are met. The proposed WOTUS rule cites the plurality + Kennedy argument almost exclusively, but completely IGNORES the dissent + Kennedy "significant nexus" controlling opinion. BOTH are controlling in this case, both are law. Both have equal weight in asserting CWA regulatory jurisdiction over waters of the United States. The declaration of goals and policy of the CWA are (CWA 101): "The objective of this Act is to restore and maintain the chemical, physical and biological integrity of the Nation's waters." The proposed WOTUS rule attempts to alter this fundamental objective by relegating CWA jurisdiction to only physical characteristics
#
# ----------

# %%
# Print comments from cluster 1
cluster_1 = X_train[kmeans.labels_ == 1]

for row in cluster_1.head(20):
    print(row)
    print('\n----------\n')
# Out:
# I Strongly Oppose EPAs Revised Definition of Waters of the United States I am writing because I am opposed to EPAs revised definition of Waters of the United States (WOTUS), as well as the specific exclusions set forth in the proposed rule. This revised definition attempts to roll back the scope of the Clean Water Act and limit protections for wetlands and waterways that drain into the Salish Sea.  Our waterways and wetlands, and the marine ecosystems these waters drain into, such as our Salish Sea, are invaluable assets to our communitiesthey provide us with sources of safe and affordable drinking water, as well as recreational areas, jobs, and wildlife habitat. We should be strengthening protections for clean water; not rolling them back. The Clean Water Act was created in recognition of the fact that water flows downstream. Small creeks and wetlands flow into the sea, as well as into our major rivers and lakes. In order to protect the waters of the United States, as directed by Congress, all waterways must receive the protections of the Clean Water Act. If an individual or corporation is allowed to pollute or destroy a stream, wetland, river, or lake, the impacts will inevitably be systemic.  This proposed rule would remove protections for more than half of our nations wetlands. There is strong scientific consensus that wetlands play a vital role in improving the quality of nearby surface and groundwater quality and flood-control as well as providing key habitat for a number of economically important fish and widlife. It would be a huge mistake to remove protections for these precious, invaluable resources. I strongly oppose the decision to no longer cover interstate waters under the Clean Water Act. We all know that pollution doesnt stay within state boundaries, and the Clean Water Act often provides downstream states with the only meaningful recourse to address pollution from upstream states.  I also oppose the proposed rules decision to exclude protections for ephemeral streams, as this change would lead to widespread degradation of our waterways and ignore the fact that ephemeral streams are inevitably connected to larger waterways. For the sake of our communities and ecosystems, the EPA should work to maximize our clean water protections. By effectively gutting the Clean Water Act, this proposed rule clearly violates the EPAs mandate to protect human health and the environment as well as the Clean Water Act objective to restore and maintain the chemical, physical, and biological integrity of the Nations waters. For these reasons, I ask that you not finalize this proposed rule, and instead work to maintain or expand Clean Water Act protections for our waterways, wetlands, and the Salish
#
# ----------
#
# The South is home to iconic American landscapes, culturally rich communities, and a flourishing outdoor industry. All of that depends on our waterways, which provide drinking water to millions of Southerners and power the regions robust economy.The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love.The protection of our water is essential to the protection of the rural communities, people and habitats of Tennessee. Please reconsider your position. As a conservative and a follower of Jesus, the things I value most in life are the living things he created. Including the plants, animals, streams and rivers and people of this county. It is our duty as Christians and serving members of government to put protections in place that will allow us to enjoy the natural wonders of our great country for generations to come. The protection of our waterways is essential to the welfare of the United States and her people. I urge you to leave the Clean Water Act intact. Please contact me at the TN Department of State should you have any questions about Tennessees opinion on this risky and ignorant proposal. Regards, Megan Crisp
#
# ----------
#
# I am vehemently opposed to the continued (and potential permanent) suspension of the Clean Water Rule.  Water is our most important natural resources.  If we relax our restrictions, we risk additional contamination to our drinking water due to run-off and other problems.  In addition, we need to preserve our non-navigable waterways such as peatland in Wisconsin and surrounding areas, as these result in carbon trapping, further helping to mitigate climate change.  For these and many other scientific reasons, I would ask that the situation be reconsidered.  Please reinstitute the Clean Water Rule.  Thank you for your consideration.
#
# ----------
#
# The availability of clean water for drinking, livelihoods, and life itself is quickly becoming a global epidemic. It is unwise economically, socially, and for health to jeopardize any water supplies, particularly clean ones.The EPAs proposal to gut the Clean Water Act by removing protections for streams and smaller waterways in the South endangers our families, and our entire country. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themsel
The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways is wrong. It's poor policy that is neither grounded in science nor public health. The Clean Water Act is fundamental environmental protection and has had bipartisan support for half a century. It is sensible and good for the American people.I ask the EPA to keep the Clean Water Act intact. Environmental Protection is the agency's mission. Do it. Regards, Deborah Carraway
#
# ----------
#
# I write to express my opposition to the Environmental Protection Agencys proposed revised definition of the Waters of the United States, or the Dirty Water Rule. This dangerous rollback would jeopardize at least one-fifth of all streams and over half of all wetlands in the United States, including waters near my community, by stripping them of vital Clean Water Act protections. The Clean Water Act works. Before the law was in place, rivers burned because of the toxic brews dumped into them by industrial facilities. We cant afford to go back to the days when polluting industries and big developers could pour dangerous chemicals and runoff into important waters around the country. Stand with people, not polluters. Withdraw this Dirty Water Rule.As an Arizonan that values my health and the health of all in my community, know that this Dirty Water Rule would harm 75-95% of the waters in our state! Ephemeral desert washed would not be protected ! The likelihood that mining waste could wash downstream is high, so it would be terrible for us!!!
#
# ----------

# %%
# Reduce dimensions with PCA
pca = PCA(n_components=50)
components = pca.fit_transform(X_data.todense())
print(pca.explained_variance_ratio_)
sum(pca.explained_variance_ratio_)
# Out:
# [0.07865532 0.03696404 0.03376775 0.02579503 0.01948889 0.01829515
#  0.01756592 0.01475533 0.01181258 0.01096682 0.0100021  0.00955997
#  0.00909082 0.00851649 0.00800158 0.00708041 0.00682713 0.00642891
#  0.00606416 0.00602254 0.00562102 0.00531833 0.00515338 0.00487707
#  0.00480726 0.00466443 0.0045415  0.00436683 0.00430667 0.00416014
#  0.00407242 0.00399116 0.00393483 0.00377886 0.00367083 0.00364278
#  0.00360191 0.00344451 0.00330627 0.00328827 0.00313842 0.00311403
#  0.00305209 0.00300127 0.00293252 0.00282195 0.00277604 0.002679
#  0.00263953 0.00260466]
# 0.4589689219175625

# %%
components.shape
# Out:
# (6549, 50)

# %%
# Re-create DF with labeled clusters
col_names = ['pca_{}'.format(i + 1) for i in range(pca.n_components_)]

pca_df = pd.DataFrame(components, columns=col_names, index=X_train.index)
pca_df['cluster'] = kmeans.labels_

pca_df.head()
# Out:
#          pca_1     pca_2     pca_3     pca_4     pca_5     pca_6     pca_7  \
# 3783  0.394497  0.200157 -0.076532 -0.129440 -0.045870 -0.001131  0.049526
# 2110  0.086650 -0.199716 -0.096333  0.329020  0.289615  0.008926  0.045549
# 2002 -0.232677 -0.210340  0.214021  0.095326 -0.081602  0.086748  0.020537
# 3047 -0.370968  0.312779  0.258571  0.032868  0.067546  0.023142  0.024890
# 418  -0.124500 -0.092041 -0.174468 -0.043638  0.001848 -0.000833  0.061268
#
#          pca_8     pca_9    pca_10    pca_11    pca_12    pca_13    pca_14  \
# 3783  0.016139  0.032957 -0.086611  0.009017  0.035661 -0.108972  0.009588
# 2110 -0.107564 -0.089524 -0.110649 -0.000541 -0.053757 -0.027338 -0.154608
# 2002  0.160838 -0.066950  0.136519 -0.016001  0.134042  0.016561 -0.063230
# 3047 -0.072646  0.027193  0.012589 -0.045815 -0.032036 -0.086926 -0.008549
# 418  -0.040074  0.006727  0.084136  0.124009  0.050043  0.015530  0.091512
#
#         pca_15    pca_16    pca_17    pca_18    pca_19    pca_20    pca_21  \
# 3783  0.019357  0.015015  0.013915  0.056888  0.003609 -0.022236  0.010098
# 2110  0.162015  0.021141  0.156871 -0.207057 -0.083226 -0.000526 -0.122563
# 2002  0.064858  0.106645 -0.051418  0.062096  0.047343 -0.008978  0.031517
# 3047  0.000526 -0.016856 -0.027280 -0.042561 -0.038927 -0.008244 -0.013800
# 418  -0.030845 -0.030566 -0.038930 -0.078151  0.007142 -0.030104  0.032947
#
#         pca_22    pca_23    pca_24    pca_25  ...    pca_27    pca_28  \
# 3783 -0.014176 -0.085816 -0.056633 -0.064483  ... -0.014805  0.009997
# 2110  0.062571  0.017672  0.048787 -0.007647  ...  0.017745 -0.021648
# 2002 -0.003005  0.092846  0.052585 -0.029000  ...  0.077641  0.055396
# 3047 -0.004241  0.014194  0.012405 -0.083143  ...  0.011891  0.000676
# 418   0.058474 -0.042960 -0.013660 -0.007602  ...  0.039920 -0.096504
#
#         pca_29    pca_30    pca_31    pca_32    pca_33    pca_34    pca_35  \
# 3783 -0.066973  0.088255 -0.042067  0.002309 -0.014189 -0.016544 -0.051747
# 2110  0.008952  0.042813 -0.014133 -0.056674 -0.019519 -0.057811  0.015734
# 2002 -0.051095  0.007261  0.013047 -0.049576 -0.026118  0.009412 -0.039551
# 3047 -0.061539  0.052871  0.041287  0.070240  0.095804 -0.033041  0.042155
# 418  -0.007193 -0.018955 -0.091804 -0.034241 -0.024898  0.002482  0.020495
#
#         pca_36    pca_37    pca_38    pca_39    pca_40    pca_41    pca_42  \
# 3783 -0.003898 -0.030344 -0.006126 -0.070356  0.047179  0.027154 -0.018887
# 2110 -0.090862  0.080340 -0.046679 -0.004673 -0.070544 -0.091342  0.105007
# 2002 -0.034875  0.034444 -0.013670 -0.021728  0.025292 -0.045313 -0.071879
# 3047 -0.066292 -0.040857  0.028616 -0.061526 -0.062520  0.008331 -0.029742
# 418   0.082072 -0.045689  0.064903 -0.015490  0.010499  0.010849 -0.025648
#
#         pca_43    pca_44    pca_45    pca_46    pca_47    pca_48    pca_49  \
# 3783  0.058892 -0.026801  0.000558 -0.002387 -0.034596  0.054067 -0.052883
# 2110  0.018199 -0.015450 -0.009780 -0.017718 -0.031588 -0.004489  0.005000
# 2002  0.052058 -0.071506  0.065766 -0.011011 -0.040664 -0.024096 -0.006940
# 3047  0.023160  0.012223 -0.012366 -0.030456  0.008106 -0.043365 -0.058110
# 418   0.031393  0.046971  0.078392  0.088684  0.112568  0.069321 -0.030413
#
#         pca_50  cluster
# 3783  0.105312        0
# 2110 -0.013154        0
# 2002  0.004541        1
# 3047  0.027224        1
# 418  -0.069247        1
#
# [5 rows x 51 columns]

# %%
# Read in labeled comment sample
labels = pd.read_excel('./Data/comments_labeled.xlsx',
                       header=0,
                       index_col=0,
                       usecols=[0, 2])

labels.dropna(inplace=True)  # only keep labeled samples
labels.shape
# Out:
# (202, 1)

# %%
samples = pd.merge(labels, pca_df[['pca_1', 'pca_2']],
                   left_index=True,
                   right_index=True)

samples.tail(10)
# Out:
#      Support_Rule_Change     pca_1     pca_2
# 193                  0.0 -0.274149  0.045823
# 194                  0.0 -0.176767  0.001131
# 195                  1.0  0.421713  0.223108
# 196                  0.0  0.173878 -0.126718
# 197                  1.0 -0.152875 -0.019376
# 200                  0.0 -0.254317  0.280534
# 201                  0.0  0.158566 -0.347664
# 202                  0.0  0.037988  0.056610
# 203                  0.0  0.020922  0.123784
# 204                  0.0 -0.221094 -0.037826

# %%
# Plot first two principal components and explained variance
plt.subplots(1, 2, figsize=(15, 6));
plt.subplot(1, 2, 1);
sns.scatterplot(x='pca_1', y='pca_2', data=pca_df, hue='cluster', alpha=0.3, palette='RdBu');
sns.scatterplot(x='pca_1', y='pca_2', data=samples, hue='Support_Rule_Change', palette='viridis');
plt.title('Principal Component Analysis');

feats = range(1, 11)
plt.subplot(1, 2, 2);
plt.bar(feats, pca.explained_variance_ratio_[:10]);
plt.xticks(feats);
plt.xlabel('PCA Feature');
plt.ylabel('Explained Variance');
plt.title('Explained Variance of Top Ten Principal Components');

# plt.savefig('./Figures/PCA_HashingL2_5000.png');

# %%
# Create and fit a KMeans algorithm using top 2 PCA features
X_pca = pca_df.loc[:, ['pca_1', 'pca_2']]

# Crude line separating clusters: y = 3/6 * x + 0.35
X_pca['small_cl'] = (X_pca['pca_2'] > X_pca['pca_1'] * 3/6 + 0.35).astype(int)

X_pca.head()
# Out:
#          pca_1     pca_2  small_cl
# 3783  0.394497  0.200157         0
# 2110  0.086650 -0.199716         0
# 2002 -0.232677 -0.210340         0
# 3047 -0.370968  0.312779         1
# 418  -0.124500 -0.092041         0

# %%
# Plot principal components and clusters
# Approximate line between two clusters
plt.figure(figsize=(10, 6));
sns.scatterplot(x='pca_1', y='pca_2', data=X_pca, hue='small_cl', alpha=0.3);
plt.plot(X_pca['pca_1'], X_pca['pca_1']*3/6 + 0.35);
plt.title('Principal Component Analysis Clustering');

# %%
import random
random.seed(42)

# %%
# Print comments from small cluster
small_cluster = X_train[X_pca['small_cl'] == 1]

for _ in range(20):
    idx = random.choice(small_cluster.index)
    print('Comment index: {}'.format(idx))
    print(X_train.loc[idx])
    print('\n----------\n')
# Out:
# Comment index: 3871
# The South is home to iconic American landscapes, culturally rich communities, and a flourishing outdoor industry. All of that depends on our waterways, which provide drinking water to millions of Southerners and power the regions robust economy.Not to mention all the millions of living things that depend on clean water to drink and to use for growth and hydration.  What are you thinking by taking away these protection? Are you trying to poison us all and kill innocents ? I mean what is your purpose?The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. Dont undo these protections to make it easier for industry to remove their waste.  Industries make a lot of money which should be put towards the proper methods of removing waste during normal production. Waste must continue to be separated and safely disposed of in the way that protects the water and environment. Dont throw away our safety and kill nature just to save a buck. Can you afford to do that ultimately?We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love. Regards, Anna Esco
#
# ----------
#
# Comment index: 2334
# I grew up near a polluted river in eastern North Carolina, and The Clean Water Act was responsible for cleaning it up.  Now it's a beautiful and useful waterway used by wildlife and for recreation.  Rolling back the protections of The Clean Water Act would be a disaster!  Don't allow big business and the current federal administration to ruin our waterways just so they can fatten up their wallets!  The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love. Regards, Vernon Janke
#
# ----------
#
# Comment index: 931
# Please do not allow the Clean Water Act to be dismantled!  We need clean water, and this act helps us be sure we have some restrictions in place.  It isn't perfect, but to dismantle it in the midst of our GenX crisis here on the Cape Fear River would really be letting the citizens down. The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love. Regards,
EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. This protection of our waters should be strengthened so we and our ecosystems we depend upon dont become weakened, lame, and sick. Why would we want to live in a country that has dirty water? Why would we support a man and governing agencies who want to sicken our people by poisoning our land, our waterways, our drinking water, our food? We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love and are fed from. Regards, Courtney DiCarlo
#
# ----------
#
# Comment index: 4357
# The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways is a bad idea. Small streams empty into rivers and lakes. Despite what polluting industries and President Trump may say, history has shown that industry cant be trusted to regulate itself. The Clean Water Act protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of our rivers, lakes, streams, and coastal waters. Regards, Carl Johnson
#
# ----------
#
# Comment index: 7659
# o. Why? Because protecting our waterways and drinking water sources is common sense. The South is my home I have lived here for 70 years. It is a beautiful land. We have Mountains and beaches. A lot of us grow our own food, and  furnish other people from different States with food. the water here needs to be kept clean. Government has enough to look after without trying to take on water management.The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years agWe ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love. Regards, Beverly Thornburg
#
# ----------
#
# Comment index: 6976
# Our city's water is already tainted with endocrine disruptors and cancer causing chemicals all because the company Chemours is dumping toxins into our river! This tributary and many more like it provide drinking water to millions of Southerners and power the regions robust economy.The EPAs proposal to gut the Clean Water Act by removing protections for our streams and smaller waterways endangers our families. Whats dumped in these tributaries will inevitably be carried to larger bodies of water throughout the region. Despite what polluting industries may say, history has shown that they cant be trusted to regulate themselves. The Clean Water Act is the bedrock environmental policy that protects Americans with basic limits on industrial pollution of our waters. It has had strong bipartisan support since it was put in place nearly 50 years ago. Why? Because protecting our waterways and drinking water sources is common sense. We ask EPA to reconsider this risky proposal and keep the Clean Water Act intact, in order to protect the health of Southern families and the rivers, lakes, streams, and coastal waters we love. Regards, Kimberly Boyce
#
# ----------

# %%
# TSNE cluster visualization
tsne = TSNE(n_components=2, perplexity=30)
tsne_res = tsne.fit_transform(X_data)

# %%
tsne_res.shape
# Out:
# (6549, 2)

# %%
# Re-create DF with TSNE results
tsne_df = pd.DataFrame(tsne_res, columns=['tsne_1', 'tsne_2'], index=X_train.index)
tsne_df['cluster'] = kmeans.labels_

tsne_df.head()
# Out:
#          tsne_1     tsne_2  cluster
# 3783   5.334044 -25.372610        0
# 2110  10.867088 -44.915253        0
# 2002  16.132757   5.168107        1
# 3047 -35.657169  20.081091        1
# 418  -20.013361  -6.323957        1

# %%
# Create TSNE sample DF
tsne_samples = pd.merge(labels, tsne_df[['tsne_1', 'tsne_2']],
                        left_index=True,
                        right_index=True)

tsne_samples.tail(10)
# Out:
#      Support_Rule_Change     tsne_1     tsne_2
# 193                  0.0 -14.728728   5.786315
# 194                  0.0  -2.796026  23.949749
# 195                  1.0  12.806684 -30.646662
# 196                  0.0 -59.013191  -4.917164
# 197                  1.0 -11.104682 -31.876089
# 200                  0.0 -18.020960  29.571747
# 201                  0.0  30.929407  14.646724
# 202                  0.0 -34.159306  -9.700859
# 203                  0.0 -28.297800  -2.474410
# 204                  0.0 -19.947735  -5.220685

# %%
# Plot the TSNE results
plt.figure(figsize=(10, 8));
sns.scatterplot(x='tsne_1', y='tsne_2', data=tsne_df, hue='cluster', alpha=0.3, palette='RdBu');
sns.scatterplot(x='tsne_1', y='tsne_2', data=tsne_samples, hue='Support_Rule_Change', palette='viridis');
plt.title('TNSE Analysis');
